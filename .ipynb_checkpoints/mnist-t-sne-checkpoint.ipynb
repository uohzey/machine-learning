# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets 
from sklearn import manifold
# %matplotlib inline

# %%
data = datasets.fetch_openml('mnist_784', version=1, return_X_y=True)
pixel_values, targets = data 
targets = targets.astype(int)

# %%
print(pixel_values.shape)
# Out:
# (70000, 784)

# %%
single_image = pixel_values[1, :].reshape(28, 28)
plt.imshow(single_image, cmap='gray')

# %%
tsne = manifold.TSNE(n_components=2, random_state=42)
transformed_data = tsne.fit_transform(pixel_values[:3000, :])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-38b7103014d4> in <module>
#       1 tsne = manifold.TSNE(n_components=2, random_state=42)
# ----> 2 transformed_data = tsne.fit_transform(pixel_values[:3000, :])
#
# c:\users\42070\appdata\local\programs\python\python36\lib\site-packages\sklearn\manifold\t_sne.py in fit_transform(self, X, y)
#     893             Embedding of the training data in low-dimensional space.
#     894         """
# --> 895         embedding = self._fit(X)
#     896         self.embedding_ = embedding
#     897         return self.embedding_
#
# c:\users\42070\appdata\local\programs\python\python36\lib\site-packages\sklearn\manifold\t_sne.py in _fit(self, X, skip_num_points)
#     698         if self.method == 'barnes_hut':
#     699             X = check_array(X, ensure_min_samples=2,
# --> 700                             dtype=[np.float32, np.float64])
#     701         else:
#     702             X = check_array(X, accept_sparse=['csr', 'csc', 'coo'],
#
# c:\users\42070\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     537         if not allow_nd and array.ndim >= 3:
#     538             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 539                              % (array.ndim, estimator_name))
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
tsne_df = pd.DataFrame(np.column_stack((transformed_data, targets[:3000])), columns=["x", "y", "targets"])
tsne_df.loc[:, "targets"] = tsne_df.targets.astype(int)

# %%
grid = sns.FacetGrid(tsne_df, hue="targets", size=8)
grid.map(plt.scatter, "x", "y").add_legend()
# Out:
# c:\users\42070\appdata\local\programs\python\python36\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
filename = "DataSet/mnist_v1/mnist.npz"

# %%
with np.load(filename) as data:
    train_examples = data['x_train']
    train_labels = data['y_train']
    test_examples = data['x_test']
    test_labels = data['y_test']

# %%
pixel_values, targets = train_examples, train_labels

# %%
print(pixel_values.shape)
# Out:
# (60000, 784)

# %%
print(targets.shape)
# Out:
# (60000,)

# %%
pixel_values = pixel_values.reshape(60000,784)

# %%
single_image = pixel_values[1, :].reshape(28, 28)
plt.imshow(single_image, cmap='gray')

# %%
tsne = manifold.TSNE(n_components=2, random_state=42)
transformed_data = tsne.fit_transform(pixel_values[:6000, :])

# %%
tsne_df = pd.DataFrame(np.column_stack((transformed_data, targets[:6000])), columns=["x", "y", "targets"])
tsne_df.loc[:, "targets"] = tsne_df.targets.astype(int)

# %%
grid = sns.FacetGrid(tsne_df, hue="targets", size=8)
grid.map(plt.scatter, "x", "y").add_legend()
